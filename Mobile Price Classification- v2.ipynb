# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Mobile Price Classification/train.csv')
dataset
# Out:
#       battery_power  blue  clock_speed  ...  touch_screen  wifi  price_range
# 0               842     0          2.2  ...             0     1            1
# 1              1021     1          0.5  ...             1     0            2
# 2               563     1          0.5  ...             1     0            2
# 3               615     1          2.5  ...             0     0            2
# 4              1821     1          1.2  ...             1     0            1
# ...             ...   ...          ...  ...           ...   ...          ...
# 1995            794     1          0.5  ...             1     0            0
# 1996           1965     1          2.6  ...             1     1            2
# 1997           1911     0          0.9  ...             1     0            3
# 1998           1512     0          0.9  ...             1     1            0
# 1999            510     1          2.0  ...             1     1            3
#
# [2000 rows x 21 columns]

# %% [markdown]
# #Pre Process

# %%
from sklearn.model_selection import train_test_split

X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X[X.columns] = sc.fit_transform(X[X.columns])
X
# Out:
#       battery_power      blue  clock_speed  ...   three_g  touch_screen      wifi
# 0         -0.902597 -0.990050     0.830779  ... -1.786861     -1.006018  0.986097
# 1         -0.495139  1.010051    -1.253064  ...  0.559641      0.994018 -1.014099
# 2         -1.537686  1.010051    -1.253064  ...  0.559641      0.994018 -1.014099
# 3         -1.419319  1.010051     1.198517  ...  0.559641     -1.006018 -1.014099
# 4          1.325906  1.010051    -0.395011  ...  0.559641      0.994018 -1.014099
# ...             ...       ...          ...  ...       ...           ...       ...
# 1995      -1.011860  1.010051    -1.253064  ...  0.559641      0.994018 -1.014099
# 1996       1.653694  1.010051     1.321096  ...  0.559641      0.994018  0.986097
# 1997       1.530773 -0.990050    -0.762748  ...  0.559641      0.994018 -1.014099
# 1998       0.622527 -0.990050    -0.762748  ...  0.559641      0.994018  0.986097
# 1999      -1.658331  1.010051     0.585621  ...  0.559641      0.994018  0.986097
#
# [2000 rows x 20 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

classifier = SVC()
classifier.fit(X_train, y_train)
score = classifier.score(X_test, y_test)
score
# Out:
# 0.89

# %%
classifier1 = SVC(kernel='poly', degree=2)
classifier1.fit(X_train, y_train)
score = classifier1.score(X_test, y_test)
score
# Out:
# 0.475

# %%
classifier2 = SVC(kernel='poly', degree=10)
classifier2.fit(X_train, y_train)
score = classifier2.score(X_test, y_test)
score
# Out:
# 0.25

# %%
classifier3 = SVC(kernel='poly')
classifier3.fit(X_train, y_train)
score = classifier3.score(X_test, y_test)
score
# Out:
# 0.8025

# %%
classifier3.degree
# Out:
# 3

# %%
classifier4 = SVC(kernel='rbf')
classifier4.fit(X_train, y_train)
score = classifier4.score(X_test, y_test)
score
# Out:
# 0.89

# %%
classifier5 = SVC(kernel='sigmoid')
classifier5.fit(X_train, y_train)
score = classifier5.score(X_test, y_test)
score
# Out:
# 0.9175

# %% [markdown]
# #Binning

# %%
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

min_value = X['battery_power'].min()
max_value = X['battery_power'].max()

bins = np.linspace(min_value,max_value,4)
bins
# Out:
# array([ 501., 1000., 1499., 1998.])

# %%
labels = ['low', 'medium', 'high']

X['battery_power'] = pd.cut(X['battery_power'], bins=bins, labels=labels, include_lowest=True)
X
# Out:
#      battery_power  blue  clock_speed  ...  three_g  touch_screen  wifi
# 0              low     0          2.2  ...        0             0     1
# 1           medium     1          0.5  ...        1             1     0
# 2              low     1          0.5  ...        1             1     0
# 3              low     1          2.5  ...        1             0     0
# 4             high     1          1.2  ...        1             1     0
# ...            ...   ...          ...  ...      ...           ...   ...
# 1995           low     1          0.5  ...        1             1     0
# 1996          high     1          2.6  ...        1             1     1
# 1997          high     0          0.9  ...        1             1     0
# 1998          high     0          0.9  ...        1             1     1
# 1999           low     1          2.0  ...        1             1     1
#
# [2000 rows x 20 columns]

# %%
plt.hist(X['battery_power'], bins=3)
# Out:
# (array([697., 641., 662.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <a list of 3 Patch objects>)

# %%
bins = [0, 666, 1333, 2000]
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

min_value = X['battery_power'].min()
max_value = X['battery_power'].max()

labels = ['low', 'medium', 'high']

X['battery_power'] = pd.cut(X['battery_power'], bins=bins, labels=labels, include_lowest=True)
plt.hist(X['battery_power'], bins=3)
# Out:
# (array([890., 242., 868.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <a list of 3 Patch objects>)

# %%
bins = [0, 1000, 1700, 2000]
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

min_value = X['battery_power'].min()
max_value = X['battery_power'].max()

labels = ['low', 'medium', 'high']

X['battery_power'] = pd.cut(X['battery_power'], bins=bins, labels=labels, include_lowest=True)
plt.hist(X['battery_power'], bins=3)
# Out:
# (array([697., 905., 398.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <a list of 3 Patch objects>)

# %% [markdown]
# #One Hot Encodeing

# %%
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

min_value = X['battery_power'].min()
max_value = X['battery_power'].max()

bins = np.linspace(min_value,max_value,4)

labels = ['low', 'medium', 'high']

X['battery_power'] = pd.cut(X['battery_power'], bins=bins, labels=labels, include_lowest=True)

d = pd.get_dummies(X['battery_power'], prefix='battery_power')
X = X.join(d)
X.drop(['battery_power'], inplace=True, axis=1)

X
# Out:
#       blue  clock_speed  ...  battery_power_medium  battery_power_high
# 0        0          2.2  ...                     0                   0
# 1        1          0.5  ...                     1                   0
# 2        1          0.5  ...                     0                   0
# 3        1          2.5  ...                     0                   0
# 4        1          1.2  ...                     0                   1
# ...    ...          ...  ...                   ...                 ...
# 1995     1          0.5  ...                     0                   0
# 1996     1          2.6  ...                     0                   1
# 1997     0          0.9  ...                     0                   1
# 1998     0          0.9  ...                     0                   1
# 1999     1          2.0  ...                     0                   0
#
# [2000 rows x 22 columns]

# %% [markdown]
# ## SVM on binning and one hot

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
classifier = SVC()
classifier.fit(X_train, y_train)
score = classifier.score(X_test, y_test)
score
# Out:
# 0.83

# %% [markdown]
# #Transformation

# %%
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

plt.hist(X['battery_power'])
# Out:
# (array([223., 199., 210., 199., 190., 185., 193., 201., 197., 203.]),
#  array([ 501. ,  650.7,  800.4,  950.1, 1099.8, 1249.5, 1399.2, 1548.9,
#         1698.6, 1848.3, 1998. ]),
#  <a list of 10 Patch objects>)

# %%
for i in X.columns:
  print(i)
  plt.hist(X[i])
  plt.show()
# Out:
# battery_power
# blue
# clock_speed
# dual_sim
# fc
# four_g
# int_memory
# m_dep
# mobile_wt
# n_cores
# pc
# px_height
# px_width
# ram
# sc_h
# sc_w
# talk_time
# three_g
# touch_screen
# wifi

# %% [markdown]
# ##fc

# %%
X['fc'].hist()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X[X.columns] = sc.fit_transform(X[X.columns])
X
# Out:
#       battery_power      blue  clock_speed  ...   three_g  touch_screen      wifi
# 0         -0.902597 -0.990050     0.830779  ... -1.786861     -1.006018  0.986097
# 1         -0.495139  1.010051    -1.253064  ...  0.559641      0.994018 -1.014099
# 2         -1.537686  1.010051    -1.253064  ...  0.559641      0.994018 -1.014099
# 3         -1.419319  1.010051     1.198517  ...  0.559641     -1.006018 -1.014099
# 4          1.325906  1.010051    -0.395011  ...  0.559641      0.994018 -1.014099
# ...             ...       ...          ...  ...       ...           ...       ...
# 1995      -1.011860  1.010051    -1.253064  ...  0.559641      0.994018 -1.014099
# 1996       1.653694  1.010051     1.321096  ...  0.559641      0.994018  0.986097
# 1997       1.530773 -0.990050    -0.762748  ...  0.559641      0.994018 -1.014099
# 1998       0.622527 -0.990050    -0.762748  ...  0.559641      0.994018  0.986097
# 1999      -1.658331  1.010051     0.585621  ...  0.559641      0.994018  0.986097
#
# [2000 rows x 20 columns]

# %%
X['fc'].hist()

# %%
X['log_fc'] = np.log(X['fc'])
X['log_fc'].hist()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# #New Feature

# %%
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

X
# Out:
#       battery_power  blue  clock_speed  ...  three_g  touch_screen  wifi
# 0               842     0          2.2  ...        0             0     1
# 1              1021     1          0.5  ...        1             1     0
# 2               563     1          0.5  ...        1             1     0
# 3               615     1          2.5  ...        1             0     0
# 4              1821     1          1.2  ...        1             1     0
# ...             ...   ...          ...  ...      ...           ...   ...
# 1995            794     1          0.5  ...        1             1     0
# 1996           1965     1          2.6  ...        1             1     1
# 1997           1911     0          0.9  ...        1             1     0
# 1998           1512     0          0.9  ...        1             1     1
# 1999            510     1          2.0  ...        1             1     1
#
# [2000 rows x 20 columns]

# %%
X['area'] = X['px_width'] * X['px_height']
X
# Out:
#       battery_power  blue  clock_speed  ...  touch_screen  wifi     area
# 0               842     0          2.2  ...             0     1    15120
# 1              1021     1          0.5  ...             1     0  1799140
# 2               563     1          0.5  ...             1     0  2167308
# 3               615     1          2.5  ...             0     0  2171776
# 4              1821     1          1.2  ...             1     0  1464096
# ...             ...   ...          ...  ...           ...   ...      ...
# 1995            794     1          0.5  ...             1     0  2309580
# 1996           1965     1          2.6  ...             1     1  1797975
# 1997           1911     0          0.9  ...             1     0  1416576
# 1998           1512     0          0.9  ...             1     1   225120
# 1999            510     1          2.0  ...             1     1   364182
#
# [2000 rows x 21 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
classifier = SVC()
classifier.fit(X_train, y_train)
score = classifier.score(X_test, y_test)
score
# Out:
# 0.31

# %% [markdown]
# #Decision tree

# %%
from sklearn import tree

X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
score
# Out:
# 0.8375

# %%
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf = tree.DecisionTreeClassifier(max_depth=3)
clf = clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
score
# Out:
# 0.7575

# %%
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf = tree.DecisionTreeClassifier(max_features=10)
clf = clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
score
# Out:
# 0.8125

# %%
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf = tree.DecisionTreeClassifier(max_leaf_nodes=5)
clf = clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
score
# Out:
# 0.735

# %%
X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

plt.figure(figsize=(30,30))
tree.plot_tree(clf, filled=True, fontsize=5)
plt.show()

# %% [markdown]
# #Random Forest

# %%
 from sklearn.ensemble import RandomForestClassifier

X = dataset.drop(['price_range'], axis=1)
y = dataset['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


clf = RandomForestClassifier()
clf.fit(X_train, y_train)

score = clf.score(X_test, y_test)
score
# Out:
# 0.87
